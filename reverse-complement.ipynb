# %% [markdown]
# <a href="https://colab.research.google.com/github/heispv/bioinformatics/blob/master/reverse-complement.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = '...'

# %%
def reverse_complement(text):
  text = text.replace('A', 'a')
  text = text.replace('C', 'c')
  text = text.replace('T', 'A')
  text = text.replace('G', 'C')
  text = text.replace('a', 'T')
  text = text.replace('c', 'G')

  return text[::-1]

# %%
def reverse_complement2(text):
    return text[::-1].translate(str.maketrans('ACGT', 'TGCA'))

# %%
reverse_complement(text)
# Out:
# '...'
